# %% [markdown]
# **Light-weight Inception U-Net : LIU-Net for Brain Tumor Segmentation**

# %%
#importing required libraries
import numpy as np
import nibabel as nib
import os
import glob
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from tifffile import imsave

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv3D, MaxPooling3D, UpSampling3D, concatenate
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam

# %%
# Defining model
def conv3d_inception_block(x, filters):
    tower_1 = Conv3D(filters, (1, 1, 1), padding='same', activation='relu')(x)
    tower_2 = Conv3D(filters, (3, 3, 3), padding='same', activation='relu')(x)
    tower_3 = Conv3D(filters, (5, 5, 5), padding='same', activation='relu')(x)
    return concatenate([tower_1, tower_2, tower_3], axis=-1)

def unet_3d_inception_lighter(input_shape):
    inputs = Input(input_shape)

    conv1 = conv3d_inception_block(inputs, 4)
    pool1 = MaxPooling3D(pool_size=(2, 2, 2))(conv1)

    conv2 = conv3d_inception_block(pool1, 8)
    pool2 = MaxPooling3D(pool_size=(2, 2, 2))(conv2)

    conv3 = conv3d_inception_block(pool2, 16)
    pool3 = MaxPooling3D(pool_size=(2, 2, 2))(conv3)

    conv4 = conv3d_inception_block(pool3, 32)
    pool4 = MaxPooling3D(pool_size=(2, 2, 2))(conv4)

    conv5 = conv3d_inception_block(pool4, 64)

    up6 = UpSampling3D(size=(2, 2, 2))(conv5)
    merge6 = concatenate([conv4, up6], axis=-1)
    conv6 = conv3d_inception_block(merge6, 32)

    up7 = UpSampling3D(size=(2, 2, 2))(conv6)
    merge7 = concatenate([conv3, up7], axis=-1)
    conv7 = conv3d_inception_block(merge7, 16)

    up8 = UpSampling3D(size=(2, 2, 2))(conv7)
    merge8 = concatenate([conv2, up8], axis=-1)
    conv8 = conv3d_inception_block(merge8, 8)

    up9 = UpSampling3D(size=(2, 2, 2))(conv8)
    merge9 = concatenate([conv1, up9], axis=-1)
    conv9 = conv3d_inception_block(merge9, 4)

    outputs = Conv3D(4, 1, activation='softmax')(conv9)
    model = Model(inputs=inputs, outputs=outputs)

    return model

# %%
# Define input shape (adjust according to your dataset)
input_shape = (128, 128, 128, 4)

# Create the model
model = unet_3d_inception_lighter(input_shape)

# Compile the model
model.compile(loss=dice_coef_loss, optimizer=Adam(learning_rate=0.0001), metrics=['accuracy', dice_coef, brats_wt, brats_tc, brats_et])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 128, 4)]   0         []
#
#  conv3d (Conv3D)             (None, 128, 128, 128, 4)     20        ['input_1[0][0]']
#
#  conv3d_1 (Conv3D)           (None, 128, 128, 128, 4)     436       ['input_1[0][0]']
#
#  conv3d_2 (Conv3D)           (None, 128, 128, 128, 4)     2004      ['input_1[0][0]']
#
#  concatenate (Concatenate)   (None, 128, 128, 128, 12)    0         ['conv3d[0][0]',
#                                                                      'conv3d_1[0][0]',
#                                                                      'conv3d_2[0][0]']
#
#  max_pooling3d (MaxPooling3  (None, 64, 64, 64, 12)       0         ['concatenate[0][0]']
#  D)
#
#  conv3d_3 (Conv3D)           (None, 64, 64, 64, 8)        104       ['max_pooling3d[0][0]']
#
#  conv3d_4 (Conv3D)           (None, 64, 64, 64, 8)        2600      ['max_pooling3d[0][0]']
#
#  conv3d_5 (Conv3D)           (None, 64, 64, 64, 8)        12008     ['max_pooling3d[0][0]']
#
#  concatenate_1 (Concatenate  (None, 64, 64, 64, 24)       0         ['conv3d_3[0][0]',
#  )                                                                   'conv3d_4[0][0]',
#                                                                      'conv3d_5[0][0]']
#
#  max_pooling3d_1 (MaxPoolin  (None, 32, 32, 32, 24)       0         ['concatenate_1[0][0]']
#  g3D)
#
#  conv3d_6 (Conv3D)           (None, 32, 32, 32, 16)       400       ['max_pooling3d_1[0][0]']
#
#  conv3d_7 (Conv3D)           (None, 32, 32, 32, 16)       10384     ['max_pooling3d_1[0][0]']
#
#  conv3d_8 (Conv3D)           (None, 32, 32, 32, 16)       48016     ['max_pooling3d_1[0][0]']
#
#  concatenate_2 (Concatenate  (None, 32, 32, 32, 48)       0         ['conv3d_6[0][0]',
#  )                                                                   'conv3d_7[0][0]',
#                                                                      'conv3d_8[0][0]']
#
#  max_pooling3d_2 (MaxPoolin  (None, 16, 16, 16, 48)       0         ['concatenate_2[0][0]']
#  g3D)
#
#  conv3d_9 (Conv3D)           (None, 16, 16, 16, 32)       1568      ['max_pooling3d_2[0][0]']
#
#  conv3d_10 (Conv3D)          (None, 16, 16, 16, 32)       41504     ['max_pooling3d_2[0][0]']
#
#  conv3d_11 (Conv3D)          (None, 16, 16, 16, 32)       192032    ['max_pooling3d_2[0][0]']
#
#  concatenate_3 (Concatenate  (None, 16, 16, 16, 96)       0         ['conv3d_9[0][0]',
#  )                                                                   'conv3d_10[0][0]',
#                                                                      'conv3d_11[0][0]']
#
#  max_pooling3d_3 (MaxPoolin  (None, 8, 8, 8, 96)          0         ['concatenate_3[0][0]']
#  g3D)
#
#  conv3d_12 (Conv3D)          (None, 8, 8, 8, 64)          6208      ['max_pooling3d_3[0][0]']
#
#  conv3d_13 (Conv3D)          (None, 8, 8, 8, 64)          165952    ['max_pooling3d_3[0][0]']
#
#  conv3d_14 (Conv3D)          (None, 8, 8, 8, 64)          768064    ['max_pooling3d_3[0][0]']
#
#  concatenate_4 (Concatenate  (None, 8, 8, 8, 192)         0         ['conv3d_12[0][0]',
#  )                                                                   'conv3d_13[0][0]',
#                                                                      'conv3d_14[0][0]']
#
#  up_sampling3d (UpSampling3  (None, 16, 16, 16, 192)      0         ['concatenate_4[0][0]']
#  D)
#
#  concatenate_5 (Concatenate  (None, 16, 16, 16, 288)      0         ['concatenate_3[0][0]',
#  )                                                                   'up_sampling3d[0][0]']
#
#  conv3d_15 (Conv3D)          (None, 16, 16, 16, 32)       9248      ['concatenate_5[0][0]']
#
#  conv3d_16 (Conv3D)          (None, 16, 16, 16, 32)       248864    ['concatenate_5[0][0]']
#
#  conv3d_17 (Conv3D)          (None, 16, 16, 16, 32)       1152032   ['concatenate_5[0][0]']
#
#  concatenate_6 (Concatenate  (None, 16, 16, 16, 96)       0         ['conv3d_15[0][0]',
#  )                                                                   'conv3d_16[0][0]',
#                                                                      'conv3d_17[0][0]']
#
#  up_sampling3d_1 (UpSamplin  (None, 32, 32, 32, 96)       0         ['concatenate_6[0][0]']
#  g3D)
#
#  concatenate_7 (Concatenate  (None, 32, 32, 32, 144)      0         ['concatenate_2[0][0]',
#  )                                                                   'up_sampling3d_1[0][0]']
#
#  conv3d_18 (Conv3D)          (None, 32, 32, 32, 16)       2320      ['concatenate_7[0][0]']
#
#  conv3d_19 (Conv3D)          (None, 32, 32, 32, 16)       62224     ['concatenate_7[0][0]']
#
#  conv3d_20 (Conv3D)          (None, 32, 32, 32, 16)       288016    ['concatenate_7[0][0]']
#
#  concatenate_8 (Concatenate  (None, 32, 32, 32, 48)       0         ['conv3d_18[0][0]',
#  )                                                                   'conv3d_19[0][0]',
#                                                                      'conv3d_20[0][0]']
#
#  up_sampling3d_2 (UpSamplin  (None, 64, 64, 64, 48)       0         ['concatenate_8[0][0]']
#  g3D)
#
#  concatenate_9 (Concatenate  (None, 64, 64, 64, 72)       0         ['concatenate_1[0][0]',
#  )                                                                   'up_sampling3d_2[0][0]']
#
#  conv3d_21 (Conv3D)          (None, 64, 64, 64, 8)        584       ['concatenate_9[0][0]']
#
#  conv3d_22 (Conv3D)          (None, 64, 64, 64, 8)        15560     ['concatenate_9[0][0]']
#
#  conv3d_23 (Conv3D)          (None, 64, 64, 64, 8)        72008     ['concatenate_9[0][0]']
#
#  concatenate_10 (Concatenat  (None, 64, 64, 64, 24)       0         ['conv3d_21[0][0]',
#  e)                                                                  'conv3d_22[0][0]',
#                                                                      'conv3d_23[0][0]']
#
#  up_sampling3d_3 (UpSamplin  (None, 128, 128, 128, 24)    0         ['concatenate_10[0][0]']
#  g3D)
#
#  concatenate_11 (Concatenat  (None, 128, 128, 128, 36)    0         ['concatenate[0][0]',
#  e)                                                                  'up_sampling3d_3[0][0]']
#
#  conv3d_24 (Conv3D)          (None, 128, 128, 128, 4)     148       ['concatenate_11[0][0]']
#
#  conv3d_25 (Conv3D)          (None, 128, 128, 128, 4)     3892      ['concatenate_11[0][0]']
#
#  conv3d_26 (Conv3D)          (None, 128, 128, 128, 4)     18004     ['concatenate_11[0][0]']
#
#  concatenate_12 (Concatenat  (None, 128, 128, 128, 12)    0         ['conv3d_24[0][0]',
#  e)                                                                  'conv3d_25[0][0]',
#                                                                      'conv3d_26[0][0]']
#
#  conv3d_27 (Conv3D)          (None, 128, 128, 128, 4)     52        ['concatenate_12[0][0]']
#
# ==================================================================================================
# Total params: 3124252 (11.92 MB)
# Trainable params: 3124252 (11.92 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
print(model.input_shape)
print(model.output_shape)
# Out:
# (None, 128, 128, 128, 4)
# (None, 128, 128, 128, 4)
